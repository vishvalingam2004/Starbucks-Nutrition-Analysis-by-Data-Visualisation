# %%
# Import Libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("starbucks.csv")

# %%
display(data)
# Out:
#     Unnamed: 0                                   item  calories   fat  carb  \
# 0            1                           8-Grain Roll       350   8.0    67
# 1            2                      Apple Bran Muffin       350   9.0    64
# 2            3                          Apple Fritter       420  20.0    59
# 3            4                        Banana Nut Loaf       490  19.0    75
# 4            5            Birthday Cake Mini Doughnut       130   6.0    17
# ..         ...                                    ...       ...   ...   ...
# 72          73        Tarragon Chicken Salad Sandwich       420  13.0    46
# 73          74                Turkey & Swiss Sandwich       390  13.0    36
# 74          75             Greek Yogurt Honey Parfait       300  12.0    44
# 75          76         Peach Raspberry Yogurt Parfait       300   4.0    57
# 76          77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60
#
#     fiber  protein      type
# ...

# %%
# EDA.
data=data.drop("Unnamed: 0",axis=1)

# %%
data
# Out:
#                                      item  calories   fat  carb  fiber  \
# 0                            8-Grain Roll       350   8.0    67      5
# 1                       Apple Bran Muffin       350   9.0    64      7
# 2                           Apple Fritter       420  20.0    59      0
# 3                         Banana Nut Loaf       490  19.0    75      4
# 4             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 72        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 73                Turkey & Swiss Sandwich       390  13.0    36      2
# 74             Greek Yogurt Honey Parfait       300  12.0    44      0
# 75         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 76  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 0        10    bakery
# 1         6    bakery
# 2         5    bakery
# ...

# %%
data.shape
# Out:
# (77, 7)

# %%
data.columns
# Out:
# Index(['item', 'calories', 'fat', 'carb', 'fiber', 'protein', 'type'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.3+ KB

# %%
sns.countplot(x=data['type'])
plt.xlabel("TYPE")
plt.ylabel("COUNT")
plt.title("Items Types Count")
plt.show()

# %%
data['type'].value_counts()
# Out:
# bakery           41
# petite            9
# bistro box        8
# hot breakfast     8
# sandwich          7
# parfait           3
# salad             1
# Name: type, dtype: int64

# %%
data['item'].unique
# Out:
# <bound method Series.unique of 0                              8-Grain Roll
# 1                         Apple Bran Muffin
# 2                             Apple Fritter
# 3                           Banana Nut Loaf
# 4               Birthday Cake Mini Doughnut
#                       ...
# 72          Tarragon Chicken Salad Sandwich
# 73                  Turkey & Swiss Sandwich
# 74               Greek Yogurt Honey Parfait
# 75           Peach Raspberry Yogurt Parfait
# 76    Strawberry & Blueberry Yogurt Parfait
# Name: item, Length: 77, dtype: object>

# %%
sns.histplot(x=data['calories'],color='yellow')
plt.title("CALORIES")
# Out:
# Text(0.5, 1.0, 'CALORIES')

# %%
sns.barplot(x=data['carb'],color='red')
plt.title("CARBOHYDARTE")
plt.show()

# %%
sns.scatterplot(data['calories'],data['carb'],hue=data['type'])
plt.title("ANALYSIS")
plt.show()
# Out:
# C:\Users\Kumaran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lineplot(data['protein'],data['fiber'],hue=data['type'])
# Out:
# C:\Users\Kumaran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='protein', ylabel='fiber'>

# %%
sns.countplot(x=data['fiber'])
plt.title("FIBER")
# Out:
# Text(0.5, 1.0, 'FIBER')

# %%
sns.scatterplot(data['carb'],data['fat'],hue=data['type'])
# Out:
# C:\Users\Kumaran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carb', ylabel='fat'>

# %%
sns.scatterplot(x=data['type'],y=data['fat'],hue=data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='fat'>

# %%
sns.scatterplot(x=data['type'],y=data['calories'],hue=data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='calories'>

# %%
sns.scatterplot(x=data['type'],y=data['carb'],hue=data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='carb'>

# %%
sns.scatterplot(x=data['type'],y=data['protein'],hue=data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='protein'>

# %%
sns.scatterplot(x=data['type'],y=data['fiber'],hue=data['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='fiber'>

# %%
sns.lineplot(data['protein'],data['calories'],hue=data['type'])
# Out:
# C:\Users\Kumaran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='protein', ylabel='calories'>

# %%
sns.pointplot(x=data['item'],y=data['carb'],hue=data['type'],color='orange')
plt.title("LIST OF ITEMS IN STARBUCKS")
# Out:
# Text(0.5, 1.0, 'LIST OF ITEMS IN STARBUCKS')

# %%
sns.lineplot(x=data['item'],y=data['fiber'],hue=data['type'],color='red')
plt.title("LIST OF ITEMS IN STARBUCKS")
# Out:
# Text(0.5, 1.0, 'LIST OF ITEMS IN STARBUCKS')

# %%
sns.scatterplot(x=data['item'],y=data['calories'],hue=data['type'])
plt.title("LIST OF ITEMS IN STARBUCKS")
# Out:
# Text(0.5, 1.0, 'LIST OF ITEMS IN STARBUCKS')

# %%
sns.barplot(x=data['item'],y=data['protein'],hue=data['type'])
plt.title("LIST OF ITEMS IN STARBUCKS")
# Out:
# Text(0.5, 1.0, 'LIST OF ITEMS IN STARBUCKS')

# %%
sns.scatterplot(x=data['item'],y=data['fat'],hue=data['type'])
plt.title("LIST OF ITEMS IN STARBUCKS")
# Out:
# Text(0.5, 1.0, 'LIST OF ITEMS IN STARBUCKS')

# %%
# BAKERY IS THE HIGHEST COUNT IN THE ANALYSED DATASET ATTRIBUTE 'TYPE'
